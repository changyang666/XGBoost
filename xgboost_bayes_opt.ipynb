# %% [markdown]
# #### Connect to Google Drive if required

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/MyDrive/FYP/Project/XGBoost/'
# Out:
# /content/drive/MyDrive/FYP/Project/XGBoost

# %%
# !pwd
# Out:
# /content/drive/MyDrive/FYP/Project/XGBoost

# %%
# install required package if using colab to run
# !pip install xgboost
# !pip install scikit-plot
# !pip install optuna
# !pip install optuna-dashboard
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.4)
# Requirement already satisfied: scikit-plot in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Requirement already satisfied: optuna-dashboard in /usr/local/lib/python3.10/dist-packages (0.15.1)
# Requirement already satisfied: bottle in /usr/local/lib/python3.10/dist-packages (from optuna-dashboard) (0.12.25)
# Requirement already satisfied: optuna>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from optuna-dashboard) (3.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from optuna-dashboard) (24.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from optuna-dashboard) (1.2.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1.0->optuna-dashboard) (1.13.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1.0->optuna-dashboard) (6.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1.0->optuna-dashboard) (1.25.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1.0->optuna-dashboard) (2.0.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1.0->optuna-dashboard) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna>=3.1.0->optuna-dashboard) (6.0.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->optuna-dashboard) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->optuna-dashboard) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->optuna-dashboard) (3.5.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=3.1.0->optuna-dashboard) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna>=3.1.0->optuna-dashboard) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.1.0->optuna-dashboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna>=3.1.0->optuna-dashboard) (2.1.5)

# %% [markdown]
# #### Import Required Library

# %%
import xgboost as xgb
from xgboost import XGBClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# #### Dataset Loading & Train, Test Split

# %%
# Dataset loading
df = pd.read_csv("data_preprocessed.csv")

# %%
# Dataset Split
from sklearn.model_selection import train_test_split

y = df[df.columns[-1]]
X = df.drop(df.columns[-1], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %% [markdown]
# #### XGBClassifier Model

# %%
# model define
baseline_model = XGBClassifier(objective='binary:logistic', n_estimators=50, max_depth=3)
baseline_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=50, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# #### Helper function

# %%
# K-fold cross val
from sklearn.model_selection import KFold

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score
from scikitplot.metrics import plot_roc, plot_confusion_matrix, plot_precision_recall

# %%
def eval_performance(y_pred, y_true, y_proba, plot=False, verbose=False):

  # confusion matrix
  if plot:
    plot_confusion_matrix(y_true, y_pred)

    # y_probas == (prob for class 0, prob for class 1)
    # y_proba == prob for class 1
    # hence, the arrange of y_probas == (1-y_proba, y_proba)
    y_probas = [[y, x] for x, y in zip(np.array(y_proba), 1-np.array(y_proba))]

    plot_roc(y_true, y_probas)

    plot_precision_recall(y_true, y_probas)
    plt.xlabel('Precision')
    plt.ylabel('Recall')
    plt.title('Precision-Recall Curve')

    plt.show()

  acc = accuracy_score(y_true, y_pred)
  recall = recall_score(y_true, y_pred)
  precision = precision_score(y_true, y_pred)
  f1 = f1_score(y_true, y_pred)
  roc_score = roc_auc_score(y_true, y_proba)

  if verbose:
    print(f"recall score: {recall:.4f}")
    print(f"Precision score: {precision:.4f}")
    print(f"F1 score: {f1:.4f}")
    print(f"ROC_AUC score: {roc_score:.4f}")
    print(f"Accuracy Score: {acc:.4f}\n")

  return acc, recall, precision, f1, roc_score

# %%
def cross_val(verbose=False, model=baseline_model):
    kfold = KFold(n_splits=5, shuffle=True, random_state=42)

    all_acc = []
    all_recall = []
    all_precision = []
    all_f1 = []
    all_roc_score = []

    all_train_acc = []
    all_train_recall = []
    all_train_precision = []
    all_train_f1 = []
    all_train_roc_score = []

    # Iterate through each fold in KFold
    for train_index, val_index in kfold.split(X_train):

        # Split data based on the current fold indices
        X_train_val, X_val = X_train.iloc[train_index], X_train.iloc[val_index]
        y_train_val, y_val = y_train.iloc[train_index], y_train.iloc[val_index]


        # train the model using train set
        model.fit(X_train_val, y_train_val)

        # Train set Eval
        y_probas = model.predict_proba(X_train_val)

        y_proba = y_probas[:, 1]

        y_pred = model.predict(X_train_val)

        train_acc, train_recall, train_precision, train_f1, train_roc_score = eval_performance(y_pred, y_train_val, y_proba)

        all_train_acc.append(train_acc)
        all_train_recall.append(train_recall)
        all_train_precision.append(train_precision)
        all_train_f1.append(train_f1)
        all_train_roc_score.append(train_roc_score)

        # Val set eval
        y_probas = model.predict_proba(X_val)

        y_proba = y_probas[:, 1]

        y_pred = model.predict(X_val)

        acc, recall, precision, f1, roc_score = eval_performance(y_pred, y_val, y_proba)

        all_acc.append(acc)
        all_recall.append(recall)
        all_precision.append(precision)
        all_f1.append(f1)
        all_roc_score.append(roc_score)

        if verbose:
          # Train set avg metrics
          print(f"\nTrain accuracy: \t{train_acc:.4f}")
          print(f"Train recall: \t\t{train_recall:.4f}")
          print(f"Train precision: \t{train_precision:.4f}")
          print(f"Train f1: \t\t{train_f1:.4f}")
          print(f"Train ROC score: \t{train_roc_score:.4f}")

          # Val set avg metrics
          print(f"\nVal accuracy: \t{acc:.4f}")
          print(f"Val recall: \t\t{recall:.4f}")
          print(f"Val precision: \t{precision:.4f}")
          print(f"Val f1: \t\t{f1:.4f}")
          print(f"Val ROC score: \t{roc_score:.4f}")

    avg_train_acc = sum(all_train_acc)/len(all_train_acc)
    avg_train_recall = sum(all_train_recall)/len(all_train_recall)
    avg_train_precision = sum(all_train_precision)/len(all_train_precision)
    avg_train_f1 = sum(all_train_f1)/len(all_train_f1)
    avg_train_roc = sum(all_train_roc_score)/len(all_train_roc_score)

    avg_val_acc = sum(all_acc)/len(all_acc)
    avg_val_recall = sum(all_recall)/len(all_recall)
    avg_val_precision = sum(all_precision)/len(all_precision)
    avg_val_f1 = sum(all_f1)/len(all_f1)
    avg_val_roc = sum(all_roc_score)/len(all_roc_score)

    if verbose:
        # Train set avg metrics
        print(f"\nAvg training accuracy: \t\t{avg_train_acc:.4f}")
        print(f"Avg training recall: \t\t{avg_train_recall:.4f}")
        print(f"Avg training precision: \t{avg_train_precision:.4f}")
        print(f"Avg training f1: \t\t{avg_train_f1:.4f}")
        print(f"Avg training ROC score: \t{avg_train_roc:.4f}")

        # Val set avg metrics
        print(f"\nAvg validation accuracy: \t{avg_val_acc:.4f}")
        print(f"Avg validation recall: \t\t{avg_val_recall:.4f}")
        print(f"Avg validation precision: \t{avg_val_precision:.4f}")
        print(f"Avg validation f1: \t\t{avg_val_f1:.4f}")
        print(f"Avg validation ROC score: \t{avg_val_roc:.4f}")

    # return training acc, val acc
    return avg_train_acc, avg_val_acc

# %% [markdown]
# #### Hyperparameter Tuning

# %%
import optuna
from optuna import samplers, pruners
import optuna_dashboard
import time
import joblib

import threading
# from google.colab import output
from optuna_dashboard import run_server

# %% [markdown]
# ![image](076_xgboost_hyperparameters.jpg)

# %%
# Hyperparameter to tune
'''
1. learning_rate - float
2. n_estimators - int
3. max_depth - int

** optional if serious overfitting
1. reg_lambda (L2 reg) - float
2. reg_alpha (L1 reg) - float
'''

def objective(trial):
    learning_rate = trial.suggest_float('learning_rate', 1e-3, 1)
    n_estimators = trial.suggest_int('n_estimators', 1, 20)
    max_depth = trial.suggest_int('max_depth', 1, 3)
    reg_lambda = trial.suggest_float('reg_lambda', 1e-3, 1)
    reg_alpha = trial.suggest_float('reg_alpha', 1e-3, 1)

    tune_model = XGBClassifier(objective='binary:logistic', learning_rate=learning_rate, n_estimators=n_estimators, max_depth=max_depth, reg_alpha=reg_alpha, reg_lambda=reg_lambda)

    # 5 fold cross val, get avg train acc and val acc
    _, val_acc = cross_val(verbose=False, model=tune_model)

    return val_acc

# %%
# Create optuna study
storage = optuna.storages.InMemoryStorage()
study = optuna.create_study(direction="maximize", storage=storage, sampler=samplers.GPSampler(), study_name="Bayesian Optimization") # using Random Sampler to perform Bayesian Optimization
# Out:
# <ipython-input-94-24a4195eb210>:3: ExperimentalWarning: GPSampler is experimental (supported from v3.6.0). The interface can change in the future.
#   study = optuna.create_study(direction="maximize", storage=storage, sampler=samplers.GPSampler(), study_name="Bayesian Optimization") # using Random Sampler to perform Bayesian Optimization
# [I 2024-07-01 13:25:49,167] A new study created in memory with name: Bayesian Optimization

# %%
# calculate the time require for randomize search
start_time = time.time()
study.optimize(objective, n_trials=150)  # Adjust number of trials as needed
end_time = time.time()

elapsed_time = end_time - start_time
print(f"Optimization Time: {elapsed_time:.4f} seconds")
# Out:
# [I 2024-07-01 13:25:49,980] Trial 0 finished with value: 0.9412871769957574 and parameters: {'learning_rate': 0.4590006686265176, 'n_estimators': 8, 'max_depth': 1, 'reg_lambda': 0.4480309224025559, 'reg_alpha': 0.9213033396488629}. Best is trial 0 with value: 0.9412871769957574.
# [I 2024-07-01 13:25:50,813] Trial 1 finished with value: 0.9456161635014698 and parameters: {'learning_rate': 0.7143484187957192, 'n_estimators': 13, 'max_depth': 2, 'reg_lambda': 0.6411757725435486, 'reg_alpha': 0.5334756980809638}. Best is trial 1 with value: 0.9456161635014698.
# [I 2024-07-01 13:25:51,620] Trial 2 finished with value: 0.9211284551149562 and parameters: {'learning_rate': 0.04818112170692214, 'n_estimators': 14, 'max_depth': 1, 'reg_lambda': 0.49510257706889294, 'reg_alpha': 0.06603238457897424}. Best is trial 1 with value: 0.9456161635014698.
# [I 2024-07-01 13:25:52,492] Trial 3 finished with value: 0.9472394305116009 and parameters: {'learning_rate': 0.29692952153431873, 'n_estimators': 18, 'max_depth': 2, 'reg_lambda': 0.3849615460186358, 'reg_alpha': 0.48842309877478346}. Best is trial 3 with value: 0.9472394305116009.
# [I 2024-07-01 13:25:53,348] Trial 4 finished with value: 0.9477805195149779 and parameters: {'learning_rate': 0.35743209401496484, 'n_estimators': 18, 'max_depth': 2, 'reg_lambda': 0.49667603198848204, 'reg_alpha': 0.5844132099861906}. Best is trial 4 with value: 0.9477805195149779.
# [I 2024-07-01 13:25:54,124] Trial 5 finished with value: 0.9384454075596922 and parameters: {'learning_rate': 0.15692801018915184, 'n_estimators': 13, 'max_depth': 1, 'reg_lambda': 0.6235773099416152, 'reg_alpha': 0.5035327407348482}. Best is trial 4 with value: 0.9477805195149779.
# [I 2024-07-01 13:25:54,901] Trial 6 finished with value: 0.9126059830866227 and parameters: {'learning_rate': 0.03193673005463456, 'n_estimators': 11, 'max_depth': 2, 'reg_lambda': 0.07923870019357132, 'reg_alpha': 0.41004843524688767}. Best is trial 4 with value: 0.9477805195149779.
# [I 2024-07-01 13:25:55,783] Trial 7 finished with value: 0.9481857415636685 and parameters: {'learning_rate': 0.45831402518724573, 'n_estimators': 18, 'max_depth': 3, 'reg_lambda': 0.7422791071684817, 'reg_alpha': 0.6720813975480677}. Best is trial 7 with value: 0.9481857415636685.
# [I 2024-07-01 13:25:56,622] Trial 8 finished with value: 0.9498098320098887 and parameters: {'learning_rate': 0.4366636061995403, 'n_estimators': 14, 'max_depth': 3, 'reg_lambda': 0.5880260966957496, 'reg_alpha': 0.15344092300365367}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:25:58,075] Trial 9 finished with value: 0.9464279799923329 and parameters: {'learning_rate': 0.4954148966629746, 'n_estimators': 16, 'max_depth': 2, 'reg_lambda': 0.8436823967454118, 'reg_alpha': 0.25904571267181525}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:02,761] Trial 10 finished with value: 0.9496741480409998 and parameters: {'learning_rate': 0.3231159961671736, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:05,122] Trial 11 finished with value: 0.9395276770593449 and parameters: {'learning_rate': 0.9999999999999999, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:06,384] Trial 12 finished with value: 0.9488620570714403 and parameters: {'learning_rate': 0.5563098888085899, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:07,494] Trial 13 finished with value: 0.9243779169079792 and parameters: {'learning_rate': 0.3538867597463309, 'n_estimators': 1, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:08,552] Trial 14 finished with value: 0.9265422729214873 and parameters: {'learning_rate': 1.0, 'n_estimators': 1, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:09,968] Trial 15 finished with value: 0.9481865649997575 and parameters: {'learning_rate': 0.27698883937294194, 'n_estimators': 17, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:11,275] Trial 16 finished with value: 0.9476446525602915 and parameters: {'learning_rate': 0.5493365379306092, 'n_estimators': 14, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:12,706] Trial 17 finished with value: 0.946697792550831 and parameters: {'learning_rate': 0.7364824088089088, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:14,171] Trial 18 finished with value: 0.9461564290687579 and parameters: {'learning_rate': 0.7048906151549279, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:17,166] Trial 19 finished with value: 0.9471042955001048 and parameters: {'learning_rate': 0.3540685415990988, 'n_estimators': 16, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:19,510] Trial 20 finished with value: 0.9481861075352637 and parameters: {'learning_rate': 0.44253951747005477, 'n_estimators': 19, 'max_depth': 3, 'reg_lambda': 0.4503401236857068, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:20,790] Trial 21 finished with value: 0.9466985244940214 and parameters: {'learning_rate': 0.25531994044404427, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 0.9999999999999999}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:22,187] Trial 22 finished with value: 0.9464273395420415 and parameters: {'learning_rate': 0.46166066400588673, 'n_estimators': 16, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:23,499] Trial 23 finished with value: 0.9458870739747534 and parameters: {'learning_rate': 0.6926156581780045, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 0.16903407777963061, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:24,668] Trial 24 finished with value: 0.9437231754257394 and parameters: {'learning_rate': 1.0, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:26,073] Trial 25 finished with value: 0.9460221174933509 and parameters: {'learning_rate': 0.6036066797608617, 'n_estimators': 17, 'max_depth': 3, 'reg_lambda': 0.43163461178642615, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:27,336] Trial 26 finished with value: 0.947646116446672 and parameters: {'learning_rate': 0.7423608216342479, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:28,741] Trial 27 finished with value: 0.9456157975298748 and parameters: {'learning_rate': 0.3415079089893577, 'n_estimators': 13, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:31,778] Trial 28 finished with value: 0.9489975580545316 and parameters: {'learning_rate': 0.4149647421454612, 'n_estimators': 15, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:33,462] Trial 29 finished with value: 0.9434508925589741 and parameters: {'learning_rate': 0.8375481663168103, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 8 with value: 0.9498098320098887.
# [I 2024-07-01 13:26:34,890] Trial 30 finished with value: 0.9502158774946683 and parameters: {'learning_rate': 0.353046520473872, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:36,208] Trial 31 finished with value: 0.9475097005345929 and parameters: {'learning_rate': 0.5698958511733994, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:37,625] Trial 32 finished with value: 0.9479162949767655 and parameters: {'learning_rate': 0.3421787445486692, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:38,868] Trial 33 finished with value: 0.9484570180085473 and parameters: {'learning_rate': 0.4449798557183985, 'n_estimators': 12, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:40,169] Trial 34 finished with value: 0.9488625145359343 and parameters: {'learning_rate': 0.32265500259829405, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.8069454029384182}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:41,483] Trial 35 finished with value: 0.947915654526474 and parameters: {'learning_rate': 0.4028798213022024, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:42,938] Trial 36 finished with value: 0.9499449670213848 and parameters: {'learning_rate': 0.3651045531569423, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:45,893] Trial 37 finished with value: 0.9453455275068826 and parameters: {'learning_rate': 0.5879989970335763, 'n_estimators': 10, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:47,708] Trial 38 finished with value: 0.9456167124588625 and parameters: {'learning_rate': 0.856831848037077, 'n_estimators': 14, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:48,955] Trial 39 finished with value: 0.948862148564339 and parameters: {'learning_rate': 0.31576024729815516, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:50,142] Trial 40 finished with value: 0.9370935084873387 and parameters: {'learning_rate': 0.7057018852369237, 'n_estimators': 6, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:51,379] Trial 41 finished with value: 0.9475102494919856 and parameters: {'learning_rate': 0.4023027268918804, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:52,694] Trial 42 finished with value: 0.9485919700342457 and parameters: {'learning_rate': 0.4139454804895834, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:53,835] Trial 43 finished with value: 0.9484572924872436 and parameters: {'learning_rate': 0.4728278888779278, 'n_estimators': 13, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 30 with value: 0.9502158774946683.
# [I 2024-07-01 13:26:55,168] Trial 44 finished with value: 0.9504861475176604 and parameters: {'learning_rate': 0.25676582833039485, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:26:56,357] Trial 45 finished with value: 0.9496744225196961 and parameters: {'learning_rate': 0.25780142175420756, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:26:58,302] Trial 46 finished with value: 0.948727471017337 and parameters: {'learning_rate': 0.22414961914295084, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:00,768] Trial 47 finished with value: 0.9423701784386005 and parameters: {'learning_rate': 1.0, 'n_estimators': 12, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:02,242] Trial 48 finished with value: 0.9498098320098884 and parameters: {'learning_rate': 0.2838877917683267, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:03,767] Trial 49 finished with value: 0.9498096490240912 and parameters: {'learning_rate': 0.2863296499745351, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.6047075038139866, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:05,096] Trial 50 finished with value: 0.9498094660382934 and parameters: {'learning_rate': 0.22086357456868, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:06,292] Trial 51 finished with value: 0.9457521219490548 and parameters: {'learning_rate': 0.8465404937057871, 'n_estimators': 16, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:07,704] Trial 52 finished with value: 0.9492682855420176 and parameters: {'learning_rate': 0.22857358873334838, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:08,888] Trial 53 finished with value: 0.9450755319625868 and parameters: {'learning_rate': 0.7754671859469958, 'n_estimators': 15, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:10,153] Trial 54 finished with value: 0.9488623315501368 and parameters: {'learning_rate': 0.5153327133632251, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:11,484] Trial 55 finished with value: 0.9479154715406765 and parameters: {'learning_rate': 0.33903046918777574, 'n_estimators': 13, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:14,206] Trial 56 finished with value: 0.946292296023444 and parameters: {'learning_rate': 0.4589832345438617, 'n_estimators': 13, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:16,508] Trial 57 finished with value: 0.9476443780815952 and parameters: {'learning_rate': 0.5728792105165271, 'n_estimators': 11, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:17,811] Trial 58 finished with value: 0.9495390130295037 and parameters: {'learning_rate': 0.24426930978385844, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:19,078] Trial 59 finished with value: 0.9476451100247854 and parameters: {'learning_rate': 0.37770957145874545, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:20,439] Trial 60 finished with value: 0.9485918785413471 and parameters: {'learning_rate': 0.31964028971187514, 'n_estimators': 14, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:21,791] Trial 61 finished with value: 0.9479161119909678 and parameters: {'learning_rate': 0.26117620857167256, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.5000265248389095, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:23,097] Trial 62 finished with value: 0.9472395220044996 and parameters: {'learning_rate': 0.576226988270576, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:24,294] Trial 63 finished with value: 0.9457515729916622 and parameters: {'learning_rate': 0.3638906916010165, 'n_estimators': 14, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:25,472] Trial 64 finished with value: 0.9456170784304577 and parameters: {'learning_rate': 0.8494533872563297, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:27,697] Trial 65 finished with value: 0.9469691604886087 and parameters: {'learning_rate': 0.5507104313887721, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:30,640] Trial 66 finished with value: 0.9504854155744702 and parameters: {'learning_rate': 0.19788013078014768, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:31,935] Trial 67 finished with value: 0.9503501890700754 and parameters: {'learning_rate': 0.19803676545282015, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:33,314] Trial 68 finished with value: 0.9503501890700754 and parameters: {'learning_rate': 0.1980349185638308, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:34,651] Trial 69 finished with value: 0.9499449670213845 and parameters: {'learning_rate': 0.19710885607678852, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:35,996] Trial 70 finished with value: 0.9495387385508074 and parameters: {'learning_rate': 0.1855204271015915, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:37,332] Trial 71 finished with value: 0.9492683770349164 and parameters: {'learning_rate': 0.22553429453427556, 'n_estimators': 18, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 44 with value: 0.9504861475176604.
# [I 2024-07-01 13:27:38,665] Trial 72 finished with value: 0.950756692019349 and parameters: {'learning_rate': 0.2238308229362667, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:39,826] Trial 73 finished with value: 0.9465629320180314 and parameters: {'learning_rate': 0.20482078786898836, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:42,780] Trial 74 finished with value: 0.9429100780342934 and parameters: {'learning_rate': 0.8039829594081851, 'n_estimators': 13, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:44,647] Trial 75 finished with value: 0.9448043470106068 and parameters: {'learning_rate': 0.597319732373391, 'n_estimators': 13, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.9999999999999999}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:45,875] Trial 76 finished with value: 0.9465630235109301 and parameters: {'learning_rate': 0.44613783481354563, 'n_estimators': 12, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:47,067] Trial 77 finished with value: 0.9476452015176843 and parameters: {'learning_rate': 0.27836880655687457, 'n_estimators': 13, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:48,361] Trial 78 finished with value: 0.9503506465345692 and parameters: {'learning_rate': 0.1871601296943939, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:49,692] Trial 79 finished with value: 0.9487270135528432 and parameters: {'learning_rate': 0.1531227105370944, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:51,078] Trial 80 finished with value: 0.9492679195704226 and parameters: {'learning_rate': 0.16902814498341318, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:52,410] Trial 81 finished with value: 0.9494034205535138 and parameters: {'learning_rate': 0.19487370912483387, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:53,690] Trial 82 finished with value: 0.9491335165021166 and parameters: {'learning_rate': 0.23558479376477476, 'n_estimators': 16, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:57,029] Trial 83 finished with value: 0.9502156030159717 and parameters: {'learning_rate': 0.19694775423942742, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.5207969755286652, 'reg_alpha': 0.473091440814541}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:27:58,757] Trial 84 finished with value: 0.9504857815460653 and parameters: {'learning_rate': 0.15000744435848276, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:00,086] Trial 85 finished with value: 0.9502150540585793 and parameters: {'learning_rate': 0.14964075763599682, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:01,479] Trial 86 finished with value: 0.9488624230430354 and parameters: {'learning_rate': 0.16225816421263103, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:02,657] Trial 87 finished with value: 0.9431811714933745 and parameters: {'learning_rate': 0.6066204551584813, 'n_estimators': 12, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:03,935] Trial 88 finished with value: 0.9502154200301745 and parameters: {'learning_rate': 0.18337917622875005, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.46945220473681154, 'reg_alpha': 0.47795580130941495}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:05,296] Trial 89 finished with value: 0.9491332420234204 and parameters: {'learning_rate': 0.1884985634904681, 'n_estimators': 18, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:06,604] Trial 90 finished with value: 0.9492689259923092 and parameters: {'learning_rate': 0.24481037786845736, 'n_estimators': 16, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:07,906] Trial 91 finished with value: 0.9477799705575851 and parameters: {'learning_rate': 0.49461634826135686, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:10,326] Trial 92 finished with value: 0.9243779169079792 and parameters: {'learning_rate': 0.6387145335288128, 'n_estimators': 1, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:12,748] Trial 93 finished with value: 0.9425053134500967 and parameters: {'learning_rate': 1.0, 'n_estimators': 14, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:14,057] Trial 94 finished with value: 0.9500799190470831 and parameters: {'learning_rate': 0.17190924016991932, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:15,539] Trial 95 finished with value: 0.9499446925426882 and parameters: {'learning_rate': 0.1501344255918498, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:16,857] Trial 96 finished with value: 0.9477798790646863 and parameters: {'learning_rate': 0.09812738590593287, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:18,148] Trial 97 finished with value: 0.9484562860653571 and parameters: {'learning_rate': 0.1741576150381822, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.521326304166431, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:19,480] Trial 98 finished with value: 0.9495391045224025 and parameters: {'learning_rate': 0.2876645169320862, 'n_estimators': 16, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:20,639] Trial 99 finished with value: 0.9466984330011228 and parameters: {'learning_rate': 0.4587377608708394, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:21,963] Trial 100 finished with value: 0.9492686515136126 and parameters: {'learning_rate': 0.23395656950669683, 'n_estimators': 18, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.38844903162737776}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:24,093] Trial 101 finished with value: 0.9435878574284458 and parameters: {'learning_rate': 0.8387264820393326, 'n_estimators': 11, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:26,672] Trial 102 finished with value: 0.9460217515217557 and parameters: {'learning_rate': 0.16385860129212748, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:27,997] Trial 103 finished with value: 0.9499449670213848 and parameters: {'learning_rate': 0.19536419152022258, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.528255281207675}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:29,316] Trial 104 finished with value: 0.9491332420234204 and parameters: {'learning_rate': 0.2163108249952084, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:30,655] Trial 105 finished with value: 0.9494037865251089 and parameters: {'learning_rate': 0.2043766359963193, 'n_estimators': 17, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:31,988] Trial 106 finished with value: 0.9498093745453946 and parameters: {'learning_rate': 0.3290332784280512, 'n_estimators': 17, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:33,253] Trial 107 finished with value: 0.9483214255325573 and parameters: {'learning_rate': 0.23849230380867942, 'n_estimators': 16, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:34,564] Trial 108 finished with value: 0.9461570695190493 and parameters: {'learning_rate': 0.30011142232564453, 'n_estimators': 17, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:35,901] Trial 109 finished with value: 0.947915654526474 and parameters: {'learning_rate': 0.17949097605254108, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:37,858] Trial 110 finished with value: 0.9488627890146306 and parameters: {'learning_rate': 0.24445814834009427, 'n_estimators': 15, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:41,347] Trial 111 finished with value: 0.9494035120464126 and parameters: {'learning_rate': 0.16289880887469205, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:42,619] Trial 112 finished with value: 0.9462921130376467 and parameters: {'learning_rate': 0.6211745199527497, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 72 with value: 0.950756692019349.
# [I 2024-07-01 13:28:44,007] Trial 113 finished with value: 0.9508917355379463 and parameters: {'learning_rate': 0.15044362683413326, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.9999999999999999, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:28:45,358] Trial 114 finished with value: 0.9484564690511545 and parameters: {'learning_rate': 0.13173237653471012, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:28:46,615] Trial 115 finished with value: 0.9476449270389878 and parameters: {'learning_rate': 0.3285070855413476, 'n_estimators': 11, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:28:47,899] Trial 116 finished with value: 0.9460226664507434 and parameters: {'learning_rate': 0.8184673147727413, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.9999999999999999}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:28:49,283] Trial 117 finished with value: 0.9494039695109062 and parameters: {'learning_rate': 0.1934152897989694, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.9999999999999999, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:28:50,575] Trial 118 finished with value: 0.9475100665061882 and parameters: {'learning_rate': 0.3562300215263177, 'n_estimators': 12, 'max_depth': 3, 'reg_lambda': 0.9999999999999999, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:28:53,432] Trial 119 finished with value: 0.9483224319544437 and parameters: {'learning_rate': 0.4723099648302726, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:28:55,935] Trial 120 finished with value: 0.9477802450362814 and parameters: {'learning_rate': 0.14220138060161444, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 2024-07-01 13:28:57,301] Trial 121 finished with value: 0.5949645968228177 and parameters: {'learning_rate': 0.001, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# [I 2024-07-01 13:28:58,535] Trial 122 finished with value: 0.5949645968228177 and parameters: {'learning_rate': 0.06736296908847121, 'n_estimators': 1, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:28:59,961] Trial 123 finished with value: 0.9452100265237913 and parameters: {'learning_rate': 0.10039911445430644, 'n_estimators': 15, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:01,182] Trial 124 finished with value: 0.9031387553855008 and parameters: {'learning_rate': 0.8438488948377972, 'n_estimators': 1, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:02,347] Trial 125 finished with value: 0.924648369916769 and parameters: {'learning_rate': 0.48930636858084825, 'n_estimators': 1, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:03,692] Trial 126 finished with value: 0.9450759894270806 and parameters: {'learning_rate': 0.9259197601790073, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:05,039] Trial 127 finished with value: 0.9407456305278865 and parameters: {'learning_rate': 0.11264427785180925, 'n_estimators': 18, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:07,994] Trial 128 finished with value: 0.9414216715569621 and parameters: {'learning_rate': 0.9313716985204085, 'n_estimators': 10, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:10,399] Trial 129 finished with value: 0.9427743025725057 and parameters: {'learning_rate': 0.08706704326684013, 'n_estimators': 13, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:11,732] Trial 130 finished with value: 0.9411521334771601 and parameters: {'learning_rate': 0.9385710330937603, 'n_estimators': 15, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:12,991] Trial 131 finished with value: 0.9461560630971626 and parameters: {'learning_rate': 0.39067216385809034, 'n_estimators': 7, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:14,098] Trial 132 finished with value: 0.934929792924122 and parameters: {'learning_rate': 1.0, 'n_estimators': 7, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:15,478] Trial 133 finished with value: 0.9453458934784778 and parameters: {'learning_rate': 0.6583810280139933, 'n_estimators': 9, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:16,836] Trial 134 finished with value: 0.9437220775109539 and parameters: {'learning_rate': 0.7515472016844372, 'n_estimators': 9, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:18,047] Trial 135 finished with value: 0.9372284605130373 and parameters: {'learning_rate': 0.5581537069342263, 'n_estimators': 7, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:19,321] Trial 136 finished with value: 0.937092959529946 and parameters: {'learning_rate': 0.36052962511736425, 'n_estimators': 7, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:22,760] Trial 137 finished with value: 0.9483208765751646 and parameters: {'learning_rate': 0.11791628325642486, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:24,859] Trial 138 finished with value: 0.9480507895379701 and parameters: {'learning_rate': 0.5261723705804328, 'n_estimators': 12, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:26,160] Trial 139 finished with value: 0.9449404884439894 and parameters: {'learning_rate': 0.9030767988103716, 'n_estimators': 15, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:27,565] Trial 140 finished with value: 0.9469697094460013 and parameters: {'learning_rate': 0.7632634383021457, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:29,060] Trial 141 finished with value: 0.9491328760518252 and parameters: {'learning_rate': 0.19973851384414562, 'n_estimators': 15, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:30,426] Trial 142 finished with value: 0.9454802965467834 and parameters: {'learning_rate': 0.41238869585531146, 'n_estimators': 10, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:31,732] Trial 143 finished with value: 0.9445347174379061 and parameters: {'learning_rate': 0.9502576802807755, 'n_estimators': 20, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:33,148] Trial 144 finished with value: 0.9442634409930273 and parameters: {'learning_rate': 0.6679029223284082, 'n_estimators': 15, 'max_depth': 3, 'reg_lambda': 1.0, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:34,763] Trial 145 finished with value: 0.9265422729214873 and parameters: {'learning_rate': 0.7382165688706046, 'n_estimators': 1, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:38,488] Trial 146 finished with value: 0.9476441036028987 and parameters: {'learning_rate': 0.7370518229451983, 'n_estimators': 16, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:40,894] Trial 147 finished with value: 0.9031387553855008 and parameters: {'learning_rate': 0.41556644745878923, 'n_estimators': 1, 'max_depth': 1, 'reg_lambda': 0.001, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:43,519] Trial 148 finished with value: 0.9466980670295275 and parameters: {'learning_rate': 0.511634000796135, 'n_estimators': 8, 'max_depth': 3, 'reg_lambda': 0.001, 'reg_alpha': 0.001}. Best is trial 113 with value: 0.9508917355379463.
# [I 2024-07-01 13:29:44,763] Trial 149 finished with value: 0.9419637669822258 and parameters: {'learning_rate': 0.9072278476322857, 'n_estimators': 10, 'max_depth': 1, 'reg_lambda': 1.0, 'reg_alpha': 1.0}. Best is trial 113 with value: 0.9508917355379463.
# Optimization Time: 235.5834 seconds

# %%
# Access best trial results
best_trial = study.best_trial
print(best_trial.params)
# Out:
# {'learning_rate': 0.15044362683413326, 'n_estimators': 20, 'max_depth': 3, 'reg_lambda': 0.9999999999999999, 'reg_alpha': 0.001}

# %%
# for analysis
joblib.dump(study, 'bayesopt_study.pkl')
joblib.dump(storage, "bayesopt_storage.pkl")
# Out:
# ['bayesopt_storage.pkl']

# %%
# read study in case required
study = joblib.load('bayesopt_study.pkl')

best_trial = study.best_trial

# %% [markdown]
# ### Evaluation

# %% [markdown]
# #### 5 fold cross validation

# %%
model = XGBClassifier(objective='binary:logistic', **best_trial.params)

# %%
cross_val(verbose=True, model=model)
# Out:
# Train accuracy: 	0.9589
# Train recall: 		0.9467
# Train precision: 	0.9526
# Train f1: 		0.9496
# Train ROC score: 	0.9934
#
# Val accuracy: 	0.9561
# Val recall: 		0.9410
# Val precision: 	0.9459
# Val f1: 		0.9434
# Val ROC score: 	0.9906
#
# Train accuracy: 	0.9576
# Train recall: 		0.9463
# Train precision: 	0.9491
# Train f1: 		0.9477
# Train ROC score: 	0.9931
#
# Val accuracy: 	0.9540
# Val recall: 		0.9390
# Val precision: 	0.9454
# Val f1: 		0.9422
# Val ROC score: 	0.9925
#
# Train accuracy: 	0.9589
# Train recall: 		0.9456
# Train precision: 	0.9516
# Train f1: 		0.9486
# Train ROC score: 	0.9936
#
# Val accuracy: 	0.9493
# Val recall: 		0.9437
# Val precision: 	0.9362
# Val f1: 		0.9400
# Val ROC score: 	0.9898
#
# Train accuracy: 	0.9613
# Train recall: 		0.9479
# Train precision: 	0.9555
# Train f1: 		0.9517
# Train ROC score: 	0.9937
#
# Val accuracy: 	0.9438
# Val recall: 		0.9205
# Val precision: 	0.9434
# Val f1: 		0.9318
# Val ROC score: 	0.9889
#
# Train accuracy: 	0.9606
# Train recall: 		0.9480
# Train precision: 	0.9548
# Train f1: 		0.9514
# Train ROC score: 	0.9936
#
# Val accuracy: 	0.9513
# Val recall: 		0.9288
# Val precision: 	0.9481
# Val f1: 		0.9384
# Val ROC score: 	0.9898
#
# Avg training accuracy: 		0.9594
# Avg training recall: 		0.9469
# Avg training precision: 	0.9527
# Avg training f1: 		0.9498
# Avg training ROC score: 	0.9935
#
# Avg validation accuracy: 	0.9509
# Avg validation recall: 		0.9346
# Avg validation precision: 	0.9438
# Avg validation f1: 		0.9391
# Avg validation ROC score: 	0.9903
# (0.9594493221260756, 0.9508917355379463)

# %%
# further split train set to train and val set

X_train_val, X_val, y_train_val, y_val = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train)

# %%
model.fit(X_train_val, y_train_val)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.15044362683413326,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=20, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# y_train_val_pred = model.predict(X_train_val)
y_val_pred = model.predict(X_val)


val_accuracy_score = accuracy_score(y_val, y_val_pred)
# print(f"Train Accuracy: {train_val_accuracy_score:.4f}")
print(f"Val Accuracy: {val_accuracy_score:.4f}")
# Out:
# Val Accuracy: 0.9398

# %% [markdown]
# #### Test Set inference

# %%
y_pred=model.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
print(acc)
# Out:
# 0.9583333333333334

# %% [markdown]
# #### Save Model

# %%
model.save_model('bayesopt_xgb_model.xgb')
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [13:47:56] WARNING: /workspace/src/c_api/c_api.cc:1240: Saving into deprecated binary model format, please consider using `json` or `ubj`. Model format will default to JSON in XGBoost 2.2 if not specified.
#   warnings.warn(smsg, UserWarning)

# %%
# Load model
'''
from xgboost import XGBClassifier

# Load the saved model object
loaded_model = XGBClassifier()
loaded_model.load_model('model.xgb')
'''
# Out:
# "\nfrom xgboost import XGBClassifier\n\n# Load the saved model object\nloaded_model = XGBClassifier()\nloaded_model.load_model('model.xgb')\n"
